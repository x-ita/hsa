# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install langchain openai tiktoken
# Out:
# Collecting langchain
#   Downloading langchain-0.0.335-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 18.0 MB/s eta 0:00:00
# Collecting openai
#   Downloading openai-1.2.4-py3-none-any.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.2/220.2 kB 16.2 MB/s eta 0:00:00
# Collecting tiktoken
#   Downloading tiktoken-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 59.1 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.8.6)
# Requirement already satisfied: anyio<4.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.7.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.2-py3-none-any.whl (28 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langsmith<0.1.0,>=0.0.63 (from langchain)
#   Downloading langsmith-0.0.64-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.23.5)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.10.13)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.2.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.25.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.10/dist-packages (from openai) (4.5.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2023.6.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain) (1.1.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.8 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2023.7.22)
# Collecting httpcore (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 9.3 MB/s eta 0:00:00
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->langchain) (23.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting h11<0.15,>=0.13 (from httpcore->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: mypy-extensions, marshmallow, jsonpointer, h11, typing-inspect, tiktoken, langsmith, jsonpatch, httpcore, httpx, dataclasses-json, openai, langchain
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# Successfully installed dataclasses-json-0.6.2 h11-0.14.0 httpcore-1.0.2 httpx-0.25.1 jsonpatch-1.33 jsonpointer-2.4 langchain-0.0.335 langsmith-0.0.64 marshmallow-3.20.1 mypy-extensions-1.0.0 openai-1.2.4 tiktoken-0.5.1 typing-inspect-0.9.0

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.utils.math import cosine_similarity
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.chains.summarize import load_summarize_chain
import pandas as pd
import numpy as np
import os
import pickle

# %%
# OpenAI API Keyを環境変数に保存
from getpass import getpass
os.environ['OPENAI_API_KEY'] = getpass('OpenAI API Key:')
# Out:
# OpenAI API Key:··········

# %%
# ディレクトリの移動
os.chdir('/content/drive/MyDrive/aozorabunko')

# %%
# 埋め込みモデルのインスタンスを作成
embeddings = OpenAIEmbeddings(model='text-embedding-ada-002')
# チャットモデルのインスタンスを作成
llm = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=0)

# %% [markdown]
# ## テキストの前処理

# %%
import re
from langchain.document_loaders import TextLoader
from langchain.docstore.document import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
# remove unneccesary lines and characters from .txt files
# ref: https://www.osaka-kyoiku.ac.jp/~kokugo/nonami/awk/rubycut_awk.html
files = [s for s in os.listdir('./files') if re.search('\.txt$', s) is not None]
docs = []
for file in files:
    with open('./files/' + file, 'r', encoding='SHIFT_JIS') as f:
        text = f.read()
    text = re.sub('\n-{30,}\n(.|\n)*?\n-{30,}\n', '', text)
    text = re.sub('［＃[^］]*?］', '', text) # ［＃…］を除く
    text = re.sub('\n(|翻訳の)底本：(.|\n)*$', '', text)
    text = re.sub('《[^》]+》', '', text) # ルビを除く
    text = re.sub('｜', '', text) # ルビの境界記号を除く
    text = re.sub('\n+$', '', text) # 最後の改行を除く
    # タイトル・作者と本文に分けDocumentsに保存
    title_author, text = text.split('\n\n', maxsplit=1)
    doc = Document(page_content=text, metadata={'title_author':title_author})
    docs.append(doc)

# %%
# 本文の文字数とトークン数
import tiktoken
for doc in docs:
    title = doc.metadata['title_author'].split('\n')[0]
    nchar = len(doc.page_content)
    ntoken = len(tiktoken.encoding_for_model('text-embedding-ada-002').encode(doc.page_content))
    print('\t'.join([title, str(nchar), str(ntoken)]))
# Out:
# 赤ずきんちゃん	3770	3744
# シンデレラ	8448	8227
# マッチ売りの少女	3487	3427
# 金太郎	3942	4059
# 瘤とり	4941	4964
# 猿かに合戦	3442	3452
# 浦島太郎	5707	5746
# 花咲かじじい	3132	3061
# 一寸法師	5692	5802
# 桃太郎	5605	5735

# %%
tiktoken.encoding_for_model('text-embedding-ada-002').encode('桃太郎')

# %% [markdown]
# ## map-reduce法で要約

# %% [markdown]
# https://python.langchain.com/docs/use_cases/summarization#option-2-map-reduce

# %%
# gpt-3.5-turboでは入出力合わせてトークン数上限が4096のため，3000トークン以内に分割する．
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=3000,
    chunk_overlap=0
    )

# %%
# 英語で返ってくる（日本語で返すこともあるかも）．
chain = load_summarize_chain(llm, chain_type="map_reduce")
split_docs = text_splitter.split_documents(docs[:1])
chain.run(split_docs) # トークン数4097以上だとエラー
# Out:
# 'Little Red Riding Hood is tricked by a wolf who eats her grandmother and disguises himself as her. A hunter rescues them and they kill the wolf. Little Red Riding Hood learns her lesson and vows to stay on the path in the forest.'

# %%
# 日本語で要約するために必要なモジュールをインポート
from langchain.chains.combine_documents.stuff import StuffDocumentsChain
#from langchain.chains.mapreduce import MapReduceChain
from langchain.chains import ReduceDocumentsChain, MapReduceDocumentsChain

# %%
# Map chain
map_template = """次のテキストは物語の一部です．この部分のあらすじを400～500字に要約してください.
{doc}""" # 指定した字数での要約は難しいらしい．120字程度になることもある．
map_prompt = PromptTemplate.from_template(map_template)
map_chain = LLMChain(llm=llm, prompt=map_prompt)

# %%
# Reduce chain
reduce_template = """次のテキストは物語のあらすじです．これをさらに簡潔に400～500字で一つの段落にまとめてください．
{doc_summaries}""" # ここでトークン数上限を超えたらエラー？
reduce_prompt = PromptTemplate.from_template(reduce_template)
reduce_chain = LLMChain(llm=llm, prompt=reduce_prompt)

# %%
# Takes a list of documents, combines them into a single string, and passes this to an LLMChain
combine_documents_chain = StuffDocumentsChain(
    llm_chain=reduce_chain, document_variable_name="doc_summaries" # document_variable_name="docs"だとエラーになった．間違いと思われるので変更
    )

# Combines and iteravely reduces the mapped documents
reduce_documents_chain = ReduceDocumentsChain(
    # This is final chain that is called.
    combine_documents_chain=combine_documents_chain,
    # If documents exceed context for `StuffDocumentsChain`
    collapse_documents_chain=combine_documents_chain,
    # The maximum number of tokens to group documents into.
    token_max=2000
    )
reduce_prompt = PromptTemplate.from_template(reduce_template)

# %%
# Combining documents by mapping a chain over them, then combining results
map_reduce_chain = MapReduceDocumentsChain(
    # Map chain
    llm_chain=map_chain,
    # Reduce chain
    reduce_documents_chain=reduce_documents_chain,
    # The variable name in the llm_chain to put the documents in
    document_variable_name="doc",
    # Return the results of the map steps in the output
    return_intermediate_steps=True,
    )

# %%
# 要約の実行
import time
results = []
summary_docs = []
for doc in docs:
    start = time.time()
    print(doc.metadata['title_author'].split('\n')[0])
    split_docs = text_splitter.split_documents([doc])
    result = map_reduce_chain({"input_documents": split_docs}, return_only_outputs=True)
    results.append(result)
    doc = Document(page_content=result['output_text'],
                   metadata={'title_author': '[要約]' + doc.metadata['title_author']})
    summary_docs.append(doc)
    print(round((time.time() - start) / 60, 1))
# Out:
# 赤ずきんちゃん
# 3.0
# シンデレラ
# 8.1
# マッチ売りの少女
# 1.5
# 金太郎
# 1.9
# 瘤とり
# 3.0
# 猿かに合戦
# 3.6
# 浦島太郎
# 4.5
# 花咲かじじい
# 2.9
# 一寸法師
# 4.8
# 桃太郎
# 2.7

# %%
# 結果を保存
with open('./mapreduce_results.pkl', 'wb') as f:
    pickle.dump(results, f)
with open('./mapreduce_summary_docs.pkl', 'wb') as f:
    pickle.dump(summary_docs, f)

# %%
# 要約結果を確認
summary_docs # 「瘤取り」の要約はハルシネーション
# Out:
# [Document(page_content='赤ずきんちゃんはおばあさんに可愛がられ、ずきんを作ってもらいました。ある日、お母さんがお菓子とぶどう酒をおばあさんに届けるよう頼みます。森の中で赤ずきんちゃんはおおかみに出会い、おばあさんの家までの道を教えますが、おおかみは赤ずきんちゃんを食べようとします。赤ずきんちゃんはお花を摘んでいる最中、おばあさんの家に戻りますが、おばあさんが変わった様子で横になっていました。おおかみが現れて赤ずきんちゃんを食べ、寝床に戻ります。かりうどが通りかかり、おおかみを見つけて鉄砲を向けますが、おばあさんがまだおなかの中にいるかもしれないと思い、おなかを切ります。赤ずきんちゃんとおばあさんは生きていて、おおかみを倒します。三人は喜び、かりうどはおおかみの毛皮を持ち帰ります。おばあさんはお菓子とぶどう酒を食べて元気を取り戻し、赤ずきんちゃんはもう二度と森に入らないことを決めます。', metadata={'title_author': '[要約]赤ずきんちゃん\nROTKAPPCHEN\nグリム兄弟\u3000Bruder Grimm\n楠山正雄訳'}),
#  Document(page_content='昔々、高飛車な妻と結婚した男性の娘、シンデレラは姉たちにいじめられながらも美しい部屋とベッドで暮らしていた。ある日、王子のダンスパーティが開かれ、姉たちはドレスを選び始める。シンデレラは行きたくないと言うが、乳母の魔法でカボチャを馬車に変えられ、パーティに送り出される。シンデレラはハツカネズミを解放し、馬に変身させ、ドブネズミを運転手に、トカゲを従者に変える。パーティで王子様と出会い、時間を忘れてしまい、急いで逃げ出すが、ガラスの靴を残してしまう。王子様は靴を拾い、シンデレラを探し始める。最終的にシンデレラが靴を履くとぴったりとはまり、姉たちは驚き、シンデレラが本当の美しい姫だったことに気づく。姉たちは謝罪し、シンデレラは王子様と結婚し、姉たちも同じ日にお城の上流階級と結婚した。', metadata={'title_author': '[要約]シンデレラ\nCINDERELLA, OR THE LITTLE GLASS SLIPPER\n―ガラスのくつのものがたり―\nアンドルー・ラング再話\u3000Andrew Lang\n大久保ゆう訳'}),
#  Document(page_content='寒いおおみそかの晩、年のいかない少女はスリッパを失い、マッチを売っても誰も買ってくれず、お腹も空いている。家に帰っても寒いだけで、お父さんに叩かれるだけだから、彼女は家に帰ろうとしない。彼女はマッチを擦って火をつけ、暖かさを感じるが、火が消えると再び寒さに包まれる。彼女はもう一本マッチを擦り、美しい食卓やクリスマスツリーを見るが、火が消えると現実に戻る。少女はマッチを一本残さず擦り、おばあさんと一緒に天国に行くことを試みるが、最終的に凍えて死んでしまう。少女が見た美しいものや天国への旅の詳細は誰も知らない。', metadata={'title_author': '[要約]マッチ売りの少女\nハンス・クリスチャン・アンデルセン\u3000Hans Christian Andersen\n矢崎源九郎訳'}),
#  Document(page_content='強い子供の金太郎は山奥で生まれ育ち、大人たちと相撲を取っても負けないほどの力を持っていた。ある日、金太郎は大きな熊と出会い、倒して家来にした。その後、うさぎや猿、鹿も家来になり、金太郎は毎朝おむすびを持って森の中へ出かけるようになった。ある日、金太郎と家来たちはすもうを取り、金太郎が一瞬で勝利し、家来たちとおむすびを分け合って食べた。その後、金太郎は家来たちを連れて帰っていった。金太郎と仲間たちは谷川のふちに出て、橋がないことに困っていたが、金太郎は大きな杉の木を倒して橋を作った。その様子を見たきこりが金太郎に興味を持ち、彼について行くことにした。金太郎は山奥の家で貞光という大将と出会い、彼の力に驚かれて都へ連れて行かれ、頼光のもとで金時と名付けられて家来になった。金時は成長し、頼光の四天王の一人となった。', metadata={'title_author': '[要約]金太郎\n楠山正雄'}),
#  Document(page_content='ある男性が自分の人生について考え、夢を追い求めるものの自信を失っている。彼は自分の選択に疑問を抱き、他の人と比較して自分の成果が十分でないと感じている。しかし、彼は夢を諦めず再び挑戦する覚悟を決め、過去の失敗から学び、新しいアプローチを試みることを決意する。彼は自分の才能と情熱を信じ、困難に立ち向かい、夢を実現するために全力を尽くす覚悟を持っている。', metadata={'title_author': '[要約]瘤とり\n楠山正雄'}),
#  Document(page_content='ある日、猿とかにはお天気が良かったので、遊びに出かけました。途中で猿は柿の種を拾い、かにはおむすびを拾いました。猿はおむすびが欲しくなり、柿の種とおむすびを交換しようと提案しました。かにも柿の種が欲しくなり、交換をしました。猿はかにをだましておむすびを手に入れ、自宅に帰りました。かには柿の種を庭にまき、芽を出すようにと言いました。すると柿の芽はどんどん成長し、大きな木になり、最終的に花が咲きました。ある日、猿が現れ、柿を食べている様子を見せつける。かには猿に柿を取ってもらうよう頼むが、猿は青い柿を投げつけてかにを殺してしまう。その後、子がにが帰ってきて親がにの死体を見つけ、猿が柿を取っていったことを知る。子がには猿に復讐したいと泣きながら思っていたが、栗、蜂、昆布、臼が現れてかたき討ちの相談を始める。臼、昆布、蜂、栗は相談の結果、子がにを連れて猿の家に行くことにしました。猿は柿を食べ過ぎてお腹が痛くなり、山に遊びに行ってしまいました。臼はみんなで猿の家に隠れて待つことにしました。夕方に猿が帰ってきて、お腹が渇いたのでやかんに手をかけると、灰の中に隠れていた栗が飛び出して猿の鼻面を突きました。猿は驚いて台所に逃げ出し、水がめの上に顔を出すと、蜂が飛び出して猿の目の上を刺しました。猿はさらに驚いて外に逃げ出し、敷居の上に寝ていた昆布が滑って倒れ、臼が重くなってしまいました。猿は苦しみながら手足をばたつかせていました。その時、子がにが現れて猿の首をはさみで挟んでしまいました。', metadata={'title_author': '[要約]猿かに合戦\n楠山正雄'}),
#  Document(page_content='浦島太郎は海で魚を釣っている最中、子供たちがカメをいじめているのを見かける。彼はカメを買い取り、助けて海に帰してあげる。数日後、カメが現れ、お礼に龍宮を見せてあげると言う。浦島はカメに連れられて龍宮に行き、乙姫さまに出迎えられる。彼は乙姫さまと楽しい日々を過ごすが、三年後にふるさとの夢を見るようになり、家族に会いたくなる。乙姫さまは心配し、玉手箱を渡し、絶対に開けないように忠告する。浦島は約束し、元の浜へ戻る。しかし、そこには何もなく、浦島は老婆に出会う。彼女は浦島太郎は300年前に竜宮に行ったまま戻ってこなかったと言う。浦島は絶望し、玉手箱を開けると老人の姿になってしまう。彼は乙姫様が言っていた宝が人間の寿命だったことに気づき、昔のことを思い出しながら海を見つめるのだった。', metadata={'title_author': '[要約]浦島太郎\n楠山正雄'}),
#  Document(page_content='おじいさんとおばあさんは子供がいなかったため、飼い犬の白を大切に育てていました。しかし、おとなりの欲ばりなおじいさんとおばあさんは白を嫌い、いじめていました。ある日、おじいさんが畑を耕していると、白が大きな木の下で土をかき立てながら鳴きました。おじいさんがその場所を掘ると、たくさんの小判が出てきました。おじいさんとおばあさんは一気にお金持ちになりました。欲ばりなおじいさんは白を借りて小判を探しに行きましたが、結局は何も見つからず、白を殺してしまいました。おじいさんとおばあさんは白の死を悲しみましたが、白の形見として木を育て、その木からは不思議なことにお米がたくさん生まれました。おとなりの欲ばりなおじいさんとおばあさんは、人のいいおじいさんとおばあさんからうすを借りて、お米をつき始めました。しかし、お米がわき出すどころか、ぷんといやなにおいがして、きたないものが出てきて、うすにあふれてしまいました。欲ばりおじいさんは怒ってうすを壊してしまいました。正直おじいさんは灰になってしまい、がっかりしながら灰をかき集めて帰りました。おじいさんは灰を庭にまいたところ、枯れ木が花になり、お庭は春のようになりました。おじいさんは喜び、他の木にも花を咲かせることにしました。殿さまが通りかかり、おじいさんに花を咲かせるように頼みました。おじいさんは灰を振りまいたところ、さくらの木が花ざかりになりました。殿さまはおじいさんをほめてごほうびを与えました。欲ばりおじいさんも同じように花を咲かせようとしましたが、花は咲かず、灰が風に舞い散って殿さまや家来の目や鼻に入りました。殿さまは怒って欲ばりおじいさんを罰しました。おじいさんはろう屋へ連れて行かれました。', metadata={'title_author': '[要約]花咲かじじい\n楠山正雄'}),
#  Document(page_content='摂津国の難波に住む夫婦は子供が欲しくて住吉の明神さまにお願いし、一寸法師という小さな赤ちゃんが生まれる。一寸法師は16歳になり、京都で出世をするために家を出ることを両親に頼み、宰相殿のお屋敷で働くことになる。一寸法師は頭が良く、お姫さまと仲良くなるが、彼女の悪戯が原因でお姫さまは追い出され、一寸法師も彼女を追いかけるが嵐に遭い流される。一寸法師は鬼と戦い、勝利するとお姫さまを介抱し、彼女のすそから鬼の忘れ物である打ち出の小槌を見つける。一寸法師は槌を振り上げて自分の背を伸ばし、宝物を打ち出し、最後に大きな舟を出して二人は日本へ帰る。一寸法師の功績が広まり、彼は堀河の少将となり、お姫さまと結婚し、家族が集まって幸せに暮らす。', metadata={'title_author': '[要約]一寸法師\n楠山正雄'}),
#  Document(page_content='おじいさんとおばあさんは毎日山で草を刈り、川で洗濯をしていました。ある日、川から大きな桃が流れてきますが、手が届かず困ってしまったおばあさんは歌を歌いながら手をたたくと、桃が再び流れてきます。おじいさんとおばあさんは喜んで桃を持ち帰り、夕方になって桃が二つに割れて中から赤ん坊が現れます。おじいさんとおばあさんは喜び、この子を神様がくれたと思い、桃太郎と名付けます。桃太郎は成長し、十五歳になった頃、外国の鬼が島に行って力を試したいと思い、おじいさんに許可を求めます。おじいさんは驚きましたが、桃太郎の決意を尊重し、おばあさんもお弁当を作ってくれました。桃太郎は犬、猿、きじと一緒に鬼が島に到着し、鬼の城に攻め込みます。鬼たちは次々に降参し、鬼の大将も桃太郎に捕まり、宝物を差し出す代わりに命を助けてもらいます。桃太郎たちは宝物を積んだ船で日本に帰り、おじいさんとおばあさんは喜びます。桃太郎は犬と猿ときじに感謝し、鬼退治の冒険を楽しんだことを話します。', metadata={'title_author': '[要約]桃太郎\n楠山正雄'})]

# %%
# 要約の長さを確認
[len(doc.page_content) for doc in summary_docs] # プロンプトの指示より長くなっているものもある
# Out:
# [385, 344, 256, 358, 176, 645, 342, 726, 315, 427]

# %%
# intermediate_stepsを見てみる
results = pd.read_pickle('./mapreduce_results.pkl')
results[6]

# %% [markdown]
# ## refine法で要約

# %% [markdown]
# https://python.langchain.com/docs/use_cases/summarization#option-3-refine

# %%
# gpt-3.5-turboでは入出力合わせてトークン数上限が4096のため，3000文字以内に分割する．
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=3000,
    chunk_overlap=50
    )

# %%
# 日本語で400-500字に要約するようプロンプトを修正．
prompt_template = """次のテキストは物語の一部です．この部分のあらすじを400字から500字で要約してください.
{text}"""
prompt = PromptTemplate.from_template(prompt_template)

refine_template = ( # 日本語にするのが難しいのでプロンプトは英語のまま日本語出力するよう変更．
    "Your job is to produce a final summary.\n"
    "We have provided an existing summary up to a certain point: {existing_answer}\n"
    "We have the opportunity to refine the existing summary "
    "(only if needed) with some more context below.\n"
    "------------\n"
    "{text}\n"
    "------------\n"
    "Given the new context, refine the original summary into 400 - 500 characters in Japanese. "
    "If the context isn't useful, return the original summary."
    )
refine_prompt = PromptTemplate.from_template(refine_template)
refine_chain = load_summarize_chain(
    llm=llm,
    chain_type="refine",
    question_prompt=prompt,
    refine_prompt=refine_prompt,
    return_intermediate_steps=True,
    input_key="input_documents",
    output_key="output_text",
    )

# %%
# 要約を実行
results = []
summary_docs = []
for doc in docs:
    start = time.time()
    print(doc.metadata['title_author'].split('\n')[0])
    split_docs = text_splitter.split_documents([doc])
    result = refine_chain({"input_documents": split_docs}, return_only_outputs=True)
    results.append(result)
    doc = Document(page_content=result['output_text'],
                   metadata={'title_author': '[要約]' + doc.metadata['title_author']})
    summary_docs.append(doc)
    print(round((time.time() - start) / 60, 1))

# %%
# 結果を保存
with open('refine_results.pkl', 'wb') as f:
    pickle.dump(results, f)
with open('refine_summary_docs.pkl', 'wb') as f:
    pickle.dump(summary_docs, f)

# %%
# 要約結果を確認
summary_docs # 「シンデレラ」「猿かに合戦」「一寸法師」でチャンクごと情報が欠落，「瘤取り」の要約はハルシネーション
# Out:
# [Document(page_content='あるところに、かわいい赤ずきんちゃんという女の子がいました。彼女はおばあさんにとても可愛がられていました。ある日、おばあさんは赤ずきんちゃんに赤いずきんを作ってあげました。それ以来、彼女は赤ずきんちゃんと呼ばれるようになりました。赤ずきんちゃんはお母さんの頼みでお菓子とぶどう酒をおばあさんのところに届ける途中、おおかみに出会いました。おおかみは赤ずきんちゃんを食べようと考え、おばあさんの家に先回りしておばあさんを食べてしまいました。赤ずきんちゃんがおばあさんの家に着くと、おおかみがおばあさんのふりをして待っていました。その後、かりうどが通りかかり、おおかみを見つけて助け出しました。おばあさんも生きていて、三人は喜びました。', metadata={'title_author': '[要約]赤ずきんちゃん\nROTKAPPCHEN\nグリム兄弟\u3000Bruder Grimm\n楠山正雄訳'}),
#  Document(page_content='シンデレラはパーティから帰宅し、元のぼろい服に戻っていたが、ガラスの靴だけが残っていた。姉たちはシンデレラの話を聞き、王子様が靴を見つけたことを伝えた。王子様は靴を持ち上げた。王子様は靴を試すために様々な女性に履かせたが、誰もぴったりとはまらなかった。靴はシンデレラの家にもやってきた。姉たちは靴を履こうとしたが、うまくいかなかった。シンデレラは靴を履いてみせ、ぴったりとはまった。姉たちは驚き、シンデレラを許しを請い、シンデレラは王子様のもとへ案内された。王子様はシンデレラが一番美しいと思った。数日後、シンデレラと王子様は結婚式を挙げた。姉たちもお城で暮らすようになり、結婚式の日に姉たちも立派な人と結婚した。', metadata={'title_author': '[要約]シンデレラ\nCINDERELLA, OR THE LITTLE GLASS SLIPPER\n―ガラスのくつのものがたり―\nアンドルー・ラング再話\u3000Andrew Lang\n大久保ゆう訳'}),
#  Document(page_content='寒いおおみそかの晩、年のいかない少女はみすぼらしい格好で街を歩いていた。彼女は大きなスリッパをはいていたが、馬車にぶつかって失くしてしまった。そのため、彼女は裸足で歩いていた。彼女はマッチを売り歩いても誰も買ってくれず、お金ももらえなかった。寒さで凍える彼女は、マッチを一本こすって暖を取ろうとするが、火はすぐに消えてしまう。彼女はもう一本マッチをこすると、美しい食卓やクリスマスツリーが現れるが、火が消えてしまう。マッチの火が消えるたびに、少女はおばあさんと一緒に天国へ行くことを願う。最後のマッチが消えると、少女は凍え死んでしまうが、人々は彼女が幸せな新年を迎えたことを知らなかった。', metadata={'title_author': '[要約]マッチ売りの少女\nハンス・クリスチャン・アンデルセン\u3000Hans Christian Andersen\n矢崎源九郎訳'}),
#  Document(page_content='むかし、強い子供の金太郎が相模国足柄山で生まれました。金太郎は力が強く、相撲でも負けませんでした。ある日、金太郎は森で大きな木を切っていると、熊が現れました。金太郎は熊を倒し、熊は金太郎の家来になりました。その後、うさぎや猿、鹿も金太郎の家来になりました。金太郎は毎朝おかあさんにおむすびをもらい、家来たちと山へ出かけました。ある日、みんなですもうを取り、勝負がつかずに終わりました。金太郎が最後に立ち、家来たちを倒しました。金太郎はみんなにおむすびを分け与え、帰っていきました。その後、金太郎は碓井貞光という侍に出会い、都へ行くことを決めます。金太郎は頼光のお目にかけられ、坂田金時と名乗り、頼光の家来となりました。', metadata={'title_author': '[要約]金太郎\n楠山正雄'}),
#  Document(page_content='ある日、男性の家に突然現れた謎の女性。彼女は男性の過去を知っているような態度を取り、男性は彼女の正体や目的を理解できない。しかし、彼女は男性に興味を持ち、彼の人生に関わるようになる。男性は戸惑いながらも彼女との交流を深め、彼女は自分の過去を明かすことを約束する。しかし、ある日彼女は突然姿を消し、男性は彼女の行方を追い求めるが見つけられない。彼女の正体や目的は謎のままだが、男性は彼女との出会いを通じて自己を見つめ直す機会を得た。おじいさんの瘤が鬼に取られた後、おじいさんは喜び勇んで家に帰り、おばあさんに瘤のことを話す。おばあさんは驚きながらも、おじいさんの変化を喜んでいた。お隣のおじいさんも同じような瘤を持っていたが、鬼に取られてしまい、おじいさんは鬼の元へ行って瘤を取り戻すために踊りを踊る。しかし、おじいさんの踊りは鬼に気に入られず、瘤を返された後、おじいさんは泣きながら山を下って行った。', metadata={'title_author': '[要約]瘤とり\n楠山正雄'}),
#  Document(page_content='ある日、猿とかにはお天気が良かったので、遊びに出かけました。途中で猿は柿の種を拾い、かにはおむすびを拾いました。お互いに自分の拾ったものを見せ合い、猿はおむすびが欲しくなりました。猿は柿の種とおむすびを取り替える提案をし、かにも種が欲しくなりました。結局、猿はかにをだましておむすびを手に入れ、満足そうに帰っていきました。かにはすぐに柿の種を庭にまき、芽が出るように願いました。するとすぐに芽が出てきました。かには毎日芽に対して成長を促す言葉をかけ、柿の木が大きくなり、枝や葉が茂り、最終的に花が咲きました。かには木に対して実をならせるように願い、柿の木は実をつけました。しかし、猿がやってきて柿を食べてしまい、かには悲しみました。その後、かにの友だちである栗、蜂、昆布、臼がかにのかたき討ちを手伝うことになりました。臼と昆布と蜂と栗は、子がにを連れて猿のうちへ出かけて行きました。猿はたんと柿を食べて、おなかがくちくなって、おなかこなしに山へでも遊びに行ったとみえて、うちにはいませんでした。', metadata={'title_author': '[要約]猿かに合戦\n楠山正雄'}),
#  Document(page_content='浦島太郎は竜宮での生活を楽しんでいましたが、三年が経ち、故郷の夢を見るようになります。彼は早く帰りたいと思い始め、乙姫さまに告げると、乙姫さまはがっかりしますが、玉手箱を渡して別れを告げます。浦島は玉手箱を大切に持ちながら竜宮を出て、再びカメの背中に乗って故郷に戻ります。故郷に戻った浦島は、家がなくなっていることに驚きます。おばあさんに聞くと、浦島太郎は300年前に消えた人物だと言われます。浦島は玉手箱を開けると、中には何も残っていませんでしたが、自分は老人になっていました。浦島は乙姫さまが寿命を入れていたのだと悟り、昔の思い出にふけりながら、故郷の海を見つめます。', metadata={'title_author': '[要約]浦島太郎\n楠山正雄'}),
#  Document(page_content='おじいさんとおばあさんは子供がいなかったため、飼い犬の白を大切に育てていました。しかし、おとなりの欲ばりなおじいさんとおばあさんは白を嫌い、いじめていました。ある日、おじいさんが畑を掘っていると、白が大きな木の下で土をかき立てながら鳴きました。おじいさんがその場所を掘ると、たくさんの小判が出てきました。おじいさんとおばあさんは一気にお金持ちになりました。欲ばりなおじいさんは白を借りに来て、畑にも小判があるはずだと思い込んで引っ張って行きました。しかし、出てきたのは石ころや汚いものばかりでした。欲ばりなおじいさんは怒り、白の頭をくわで殴ってしまいました。白は死んでしまい、おじいさんとおばあさんは悲しみました。彼らは白の死体を埋め、その上に小さな松の木を植えました。すると、その松の木はすぐに大きく成長しました。おじいさんはその木を切ってうすを作り、お米をついていました。不思議なことに、つくたびにお米が増え続け、台所いっぱいになってしまいました。その後、おじいさんは殿さまに呼ばれ、さくらの木に花を咲かせることに成功し、ごほうびをもらいました。しかし、欲ばりなおじいさんも同じことを試みましたが失敗し、罰を受けました。', metadata={'title_author': '[要約]花咲かじじい\n楠山正雄'}),
#  Document(page_content='宰相殿のお姫さまを連れて旅に出た一寸法師は、鬼の島で鬼を倒し、宝物を手に入れて帰国するという話が広まり、天子さまの耳にも入りました。天子さまは一寸法師の身分を調べ、彼を堀河の少将として位を与えました。堀河の少将は三条宰相殿の許しを得て、お姫さまと結婚し、家族と共に幸せに過ごしました。', metadata={'title_author': '[要約]一寸法師\n楠山正雄'}),
#  Document(page_content='おじいさんとおばあさんは、毎日おじいさんが山で草を刈り、おばあさんが川で洗濯をしていました。ある日、おばあさんが洗濯をしていると、川上から大きな桃が流れてきました。おじいさんとおばあさんは喜んで桃を持ち帰り、夕方になっておじいさんが帰ってきた時、おばあさんは桃を見せて驚かせました。桃を割ると中から元気な赤ん坊が現れ、おじいさんとおばあさんは喜び、桃太郎と名付けました。桃太郎は成長し、強くなりました。ある日、桃太郎は犬、猿、きじと出会い、彼らを仲間に加えました。一緒に船に乗り、鬼の島に向かう桃太郎と仲間たち。鬼の城を見つけた彼らは、勇気を持って鬼と戦う覚悟を決めました。桃太郎と仲間たちは鬼を倒し、宝物を手に入れて帰還し、おじいさんとおばあさんは喜びました。', metadata={'title_author': '[要約]桃太郎\n楠山正雄'})]

# %% [markdown]
# ## 要約前の元のテキストをチャンクに分割

# %%
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=500,
    chunk_overlap=0)
chunk_docs = text_splitter.split_documents(docs)
with open ('./chunk_docs.pkl', 'wb') as f:
    pickle.dump(chunk_docs, f)

# %% [markdown]
# ## 埋め込みベクトルをndarrayで保存
# （Chromaでトークン数上限以上の文章をベクトル化する方法がわからないので）

# %%
# map-reduce法による要約と元の本文のチャンクのDocumentを結合
with open('./mapreduce_summary_docs.pkl', 'rb') as f:
    summary_docs = pickle.load(f)
with open ('./chunk_docs.pkl', 'rb') as f:
    chunk_docs = pickle.load(f)
summary_chunk_docs = summary_docs + chunk_docs
with open('./summary_chunk_docs.pkl', 'wb') as f:
    pickle.dump(summary_chunk_docs, f)

len(summary_chunk_docs)
# Out:
# 186

# %%
# チャンクをベクトルに埋め込み，結合してアレイに
# [embeddings.embed_query(doc.page_content) for doc in summary_chunk_docs]だとRateLimitErrorになるのでsleepさせる
embeddings_list = []
time.sleep(420)
for i, doc in enumerate(summary_chunk_docs):
    print(i)
    embeddings_list.append(embeddings.embed_query(doc.page_content))
    time.sleep(420)

embeddings_array = np.array(embeddings_list)

# 結合したアレイを保存
with open('./summary_chunk_embeddings_array.pkl', 'wb') as f:
    pickle.dump(embeddings_array, f)
embeddings_array.shape
# Out:
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# (186, 1536)
